# %%
import os
import pandas as pd
import numpy as np
import scipy as st
import matplotlib.pyplot as plt
import pathlib as path

# %%
marvel_vs_dc_df = pd.read_csv('Marvel Vs DC NEW.csv')
marvel_dc_movie_df = pd.read_csv('dc_marvel_movie_performance.csv')
mcu_boxoffice_df = pd.read_csv('mcu_box_office.csv')

#merged_df = pd.merge(marvel_vs_dc_df, marvel_dc_movie_df, mcu_boxoffice_df, how = 'left', on=)

#merged_df.head()                     
marvel_dc_movie_df.dtypes
# Out:
# Film                                             object
# U.S. release date                                object
# Box office gross Domestic (U.S. and Canada )     object
# Box office gross Other territories               object
# Box office gross Worldwide                       object
# Budget                                           object
# MCU                                                bool
# Phase                                           float64
# Distributor                                      object
# MPAA Rating                                      object
# Length                                           object
# Minutes                                           int64
# Franchise                                        object
# Character Family                                 object
# Domestic %                                       object
# Gross to Budget                                 float64
# Rotten Tomatoes Critic Score                      int64
# ...

# %%
#Marvel types

marvel_dc_movie_df.head()
# Out:
#               Film U.S. release date  \
# 0         Superman        15/12/1978
# 1      Superman II        19/06/1981
# 2     Superman III        17/06/1983
# 3        Supergirl        21/11/1984
# 4  Howard the Duck        01/08/1986
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                              $134,478,449.00
# 1                              $108,185,706.00
# 2                               $59,950,623.00
# 3                               $14,296,438.00
# 4                               $16,295,774.00
#
#   Box office gross Other territories Box office gross Worldwide  \
# 0                    $166,000,000.00            $300,478,449.00
# 1                    $108,200,000.00            $216,385,706.00
# 2                     $20,300,000.00             $80,250,623.00
# 3                                NaN             $14,296,438.00
# 4                     $21,667,000.00             $37,962,774.00
#
# ...

# %%
grouped_movie_df = marvel_dc_movie_df.groupby(['Franchise', 'Male/Female-led', 'Budget'])
grouped_movies = pd.DataFrame(grouped_movie_df['Male/Female-led'].count())
grouped_movies
#maybe add bin size?
# Out:
#                                            Male/Female-led
# Franchise Male/Female-led Budget
# DC        Co-starring     $10,000,000.00                 1
#           Female          $100,000,000.00                1
#                           $149,000,000.00                1
#                           $200,000,000.00                1
#                           $35,000,000.00                 1
# ...                                                    ...
# Marvel    Male            $75,000,000.00                 2
#                           $78,000,000.00                 1
#                           $9,000,000.00                  1
#                           $90,000,000.00                 1
#                           $97,000,000.00                 1
#
# [78 rows x 1 columns]

# %%
#generate pie chart VISUALIZATION #1
male_vs_female = grouped_movies[['Franchise','Male/Female-led']]
male_female_counts = male_vs_female['Male/Female-led'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(male_female_counts, labels=male_female_counts.index, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Distribution of Male vs Female Led Films')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 #generate pie chart VISUALIZATION #1
# ----> 2 male_vs_female = grouped_movies[['Franchise','Male/Female-led']]
#       3 male_female_counts = male_vs_female['Male/Female-led'].value_counts()
#       4 plt.figure(figsize=(8,6))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
#generate pie chart VISUALIZATION #2 - Budget vs male/female
male_vs_female_pyplot = grouped_movies['Male/Female-led'].value_counts()
plt.figure(figsize=(10, 5))
plt.bar(male_vs_female_pyplot.index, male_vs_female_pyplot.values)
plt.xlabel('Male/Female-led')
plt.ylabel('Budget')
plt.title('Franchise vs Male/Female Lead')
plt.xticks(rotation=45)
plt.show()

##Need to add BUDGET in here! 10/14/24 @4:27pm - chart doesnt make sense because it's looking at value counts need to fix this.
